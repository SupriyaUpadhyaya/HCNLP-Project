# %% [markdown]
# <a href="https://colab.research.google.com/github/SupriyaUpadhyaya/HCNLP-Text2Sql-Project/blob/main/evaluation/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
excel_files = ['Aggregation.xlsx', 'Basic SQL.xlsx', 'CTEs.xlsx', 'Multiple_joins.xlsx',
               'Set operations.xlsx', 'Single join.xlsx', 'Subqueries.xlsx', 'Window functions.xlsx']

# %%
# Iterate through each Excel file
for file in excel_files:
    df = pd.read_excel(file)
    min_bleu = df['Bleu Score'].min()
    max_bleu = df['Bleu Score'].max()
    min_rouge = df['Rouge Score'].min()
    max_rouge = df['Rouge Score'].max()

    print(f"File: {file}")
    print("Minimum Bleu Score:", min_bleu)
    print("Maximum Bleu Score:", max_bleu)
    print("Minimum Rouge Score:", min_rouge)
    print("Maximum Rouge Score:", max_rouge)
    print()
# Out:
# File: Aggregation.xlsx
# Minimum Bleu Score: 4.726550448515237e-155
# Maximum Bleu Score: 0.7369231628533763
# Minimum Rouge Score: 0.2948232323232323
# Maximum Rouge Score: 0.9156223893065999
#
# File: Basic SQL.xlsx
# Minimum Bleu Score: 5.635809992474887e-232
# Maximum Bleu Score: 1.0
# Minimum Rouge Score: 0.1545454545454545
# Maximum Rouge Score: 1.0
#
# File: CTEs.xlsx
# Minimum Bleu Score: 3.865846993487796e-155
# Maximum Bleu Score: 0.5952442267026404
# Minimum Rouge Score: 0.205026455026455
# Maximum Rouge Score: 0.8547619047619047
#
# File: Multiple_joins.xlsx
# Minimum Bleu Score: 2.253476677444321e-232
# Maximum Bleu Score: 0.6282309601364979
# Minimum Rouge Score: 0.1897233201581028
# Maximum Rouge Score: 0.9515406162464987
#
# File: Set operations.xlsx
# Minimum Bleu Score: 6.31884043540513e-232
# Maximum Bleu Score: 0.9306048591020997
# Minimum Rouge Score: 0.1708930341533748
# Maximum Rouge Score: 1.0
#
# File: Single join.xlsx
# Minimum Bleu Score: 4.640985649354196e-232
# Maximum Bleu Score: 0.6960159732944019
# Minimum Rouge Score: 0.1452353469283058
# Maximum Rouge Score: 0.9182539682539682
#
# File: Subqueries.xlsx
# Minimum Bleu Score: 1.288229753919415e-231
# Maximum Bleu Score: 1.0
# Minimum Rouge Score: 0.2394957983193278
# Maximum Rouge Score: 1.0
#
# File: Window functions.xlsx
# Minimum Bleu Score: 2.946173345580876e-232
# Maximum Bleu Score: 0.3528573301438501
# Minimum Rouge Score: 0.1589850332044801
# Maximum Rouge Score: 0.714028314028314

# %%
axes = axes.flatten()
dfs = []
for i, file in enumerate(excel_files):
    print(file)
    data = pd.read_excel(file)
    dfs.append(data)
    #axes[i].boxplot(df['Bleu Score'])
    #axes[i].set_title(f'Bleu Score {file}')
    #axes[i].set_xticks([1])
    #axes[i].set_xticklabels(['Bleu Score'])
merged_df = pd.concat(dfs, ignore_index=True)
merged_df.head()
# Out:
# Aggregation.xlsx
# Basic SQL.xlsx
# CTEs.xlsx
# Multiple_joins.xlsx
# Set operations.xlsx
# Single join.xlsx
# Subqueries.xlsx
# Window functions.xlsx
#    id                      domain  \
# 0   1                   aerospace
# 1   6               public health
# 2  13                 agriculture
# 3  17                philanthropy
# 4  21  sustainable infrastructure
#
#                                   domain_description sql_complexity  \
# 0  Aircraft manufacturing data, satellite deploym...    aggregation
# 1  Community health statistics, infectious diseas...    aggregation
# 2  Comprehensive data on agroecology, food justic...    aggregation
# 3  Philanthropy data on effective altruism, impac...    aggregation
# 4  Green building data, renewable energy infrastr...    aggregation
#
#                           sql_complexity_description            sql_task_type  \
# 0  aggregation functions (COUNT, SUM, AVG, MIN, M...  analytics and reporting
# 1  aggregation functions (COUNT, SUM, AVG, MIN, M...  analytics and reporting
# 2  aggregation functions (COUNT, SUM, AVG, MIN, M...  analytics and reporting
# 3  aggregation functions (COUNT, SUM, AVG, MIN, M...  analytics and reporting
# 4  aggregation functions (COUNT, SUM, AVG, MIN, M...  analytics and reporting
#
#                            sql_task_type_description  \
# 0  generating reports, dashboards, and analytical...
# 1  generating reports, dashboards, and analytical...
# 2  generating reports, dashboards, and analytical...
# 3  generating reports, dashboards, and analytical...
# 4  generating reports, dashboards, and analytical...
#
#                                           sql_prompt  \
# 0  What are the top 5 suppliers by total value of...
# 1  What is the total number of hospital beds in e...
# 2  How many urban agriculture projects were initi...
# 3  What is the average donation amount by quarter...
# 4  What are the top 3 cities with the highest tot...
#
#                                          sql_context  \
# 0  CREATE TABLE Suppliers (supplier_id INT, suppl...
# 1  CREATE TABLE Beds (State VARCHAR(50), Beds INT...
# 2  CREATE TABLE urban_agriculture_projects (proje...
# 3  CREATE TABLE donations (id INT, donor VARCHAR(...
# 4  CREATE TABLE renewable_energy_projects (city V...
#
#                                                  sql  \
# 0  SELECT supplier_name, SUM(total_value) as tota...
# 1  SELECT State, SUM(Beds) FROM Beds GROUP BY State;
# 2  SELECT initiation_year, COUNT(*) as num_projec...
# 3  SELECT EXTRACT(QUARTER FROM donation_date) as ...
# 4  SELECT city, SUM(capacity) FROM renewable_ener...
#
#                                      sql_explanation  \
# 0  Filters the Suppliers table based on year 2020...
# 1  This query calculates the total number of hosp...
# 2  The SQL query calculates the number of urban a...
# 3  The SQL query calculates the average donation ...
# 4  The SQL query uses the GROUP BY clause to find...
#
#                                                 text  \
# 0  ### Instruction:\nYou are a powerful text-to-S...
# 1  ### Instruction:\nYou are a powerful text-to-S...
# 2  ### Instruction:\nYou are a powerful text-to-S...
# 3  ### Instruction:\nYou are a powerful text-to-S...
# 4  ### Instruction:\nYou are a powerful text-to-S...
#
#                                      generated_query  exact_match  \
# 0  SELECT supplier_name, total_value FROM Supplie...           25
# 1  SELECT State, SUM(Beds) FROM Beds GROUP BY Sta...           74
# 2  SELECT COUNT(initiation_year) FROM urban_agric...           83
# 3  SELECT AVG(amount) FROM donations WHERE donati...           91
# 4  SELECT city, SUM(capacity) FROM renewable_ener...          199
#
#       bleu_score  rouge_score     Bleu Score  Rouge Score
# 0   3.102861e-01     0.705628   3.102861e-01     0.705628
# 1   3.889056e-01     0.633700   3.889056e-01     0.633700
# 2  4.726550e-155     0.370690  4.726550e-155     0.370690
# 3   1.322915e-01     0.497619   1.322915e-01     0.497619
# 4   4.371707e-01     0.650200   4.371707e-01     0.650200

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Use sns.boxplot() to create the box plot
#sns.boxplot(x='sql_complexity', y='bleu_score', data=merged_df)
#sns.boxplot(data=titanic, x="class", y="age", hue="alive")
plt.figure(figsize=(11,6))
# create 3rd grouped boxplot
sns.boxplot(x = merged_df['sql_complexity'],
			y = merged_df['Bleu Score'],
			hue = merged_df['sql_complexity'],
			palette = 'husl')


# Add labels and title
plt.xlabel('SQL Complexity')
plt.ylabel('Bleu Score')
plt.title('Box Plot of Bleu Score for Each SQL Complexity - For gretelai/synthetic_text_to_sql')
# Out:
# Text(0.5, 1.0, 'Box Plot of Bleu Score for Each SQL Complexity - For gretelai/synthetic_text_to_sql')

# %%
len(merged_df)
# Out:
# 1000

# %%
selected_df = merged_df[['Bleu Score', 'Rouge Score']]

# Create box plot using seaborn
sns.boxplot(data=selected_df)

# Add labels and title
plt.xlabel('Score Type')
plt.ylabel('Score')
plt.title('Box Plot of BLEU Score and ROGUE Score - For gretelai/synthetic_text_to_sql')

# Show the plot
plt.show()
